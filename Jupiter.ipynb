# %%
import Main
import pandas
import jinja2
import Inputs

df = Main.Materias.df
df.style.hide(axis="index")
# Out:
# ...
# <style type="text/css">
# </style>
# <table id="T_ddf3d">
#   <thead>
#     <tr>
#       <th id="T_ddf3d_level0_col0" class="col_heading level0 col0" >Semestre</th>
#       <th id="T_ddf3d_level0_col1" class="col_heading level0 col1" >Nome</th>
#       <th id="T_ddf3d_level0_col2" class="col_heading level0 col2" >Créditos</th>
#       <th id="T_ddf3d_level0_col3" class="col_heading level0 col3" >Dias</th>
#       <th id="T_ddf3d_level0_col4" class="col_heading level0 col4" >Horários</th>
#       <th id="T_ddf3d_level0_col5" class="col_heading level0 col5" >Precedência</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ddf3d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ddf3d_row0_col1" class="data row0 col1" >Cálculo I</td>
#       <td id="T_ddf3d_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_ddf3d_row0_col3" class="data row0 col3" >Segunda</td>
# ...
